# %%
import numpy as np 
1+1-1*(1+1-1)/1+1*(-1)
# Out:
# 0.0

# %%
mango=10
manzana=5
aguacate=15
2*aguacate+4*manzana+1.5*mango
# Out:
# 65.0

# %%
#type(1)
#type(1.5)
#type("hola")
#type(True)
type(False)
# Out:
# bool

# %%
#estrucutura nombre string /millones int/pertence bool
ejemplo=['nombre',1576, True]
ejemplo
# Out:
# ['nombre', 1576, True]

# %%
fbk=['Facebook', 2000, True]
twtr=['Twitter', 500, False]
ig=['Instagram', 1000, True]
yt=['Youtube', 3000, False]
lkn=['LinkedIn', 700, False]
wsp=['WhatsApp', 2500, True]
redes_sociales=[fbk, twtr, ig, yt, lkn, wsp]
redes_sociales
# Out:
# [['Facebook', 2000, True],
#  ['Twitter', 500, False],
#  ['Instagram', 1000, True],
#  ['Youtube', 3000, False],
#  ['LinkedIn', 700, False],
#  ['WhatsApp', 2500, True]]

# %%
nombres_rrss=['Facebook','Twitter','Instagram','Youtube','LinkedIn','WhatsApp']
print(nombres_rrss[0])
print(nombres_rrss[2])
print(nombres_rrss[0:3])
print(nombres_rrss[-1])
print(nombres_rrss[-2])
# Out:
# Facebook
# Instagram
# ['Facebook', 'Twitter', 'Instagram']
# WhatsApp
# LinkedIn

# %%
fbk.append(2006)
ig.append(2010)
yt.append(2005)
lkn.append(2003)
wsp.append(2009)
#como hacer q baje cada array del otro array
print(fbk)
print(ig)
print(yt)
print(lkn)
print(wsp)

print(fbk, ig, yt, lkn, wsp)
# Out:
# ['Facebook', 2000, True, 2006, 2006, 2006, 2006, 2006, 2006, 2006]
# ['Instagram', 1000, True, 2010, 2010, 2010, 2010, 2010]
# ['Youtube', 3000, False, 2005, 2005, 2005, 2005, 2005]
# ['LinkedIn', 700, False, 2003, 2003, 2003, 2003, 2003]
# ['WhatsApp', 2500, True, 2009, 2009, 2009, 2009, 2009]
# ['Facebook', 2000, True, 2006, 2006, 2006, 2006, 2006, 2006, 2006] ['Instagram', 1000, True, 2010, 2010, 2010, 2010, 2010] ['Youtube', 3000, False, 2005, 2005, 2005, 2005, 2005] ['LinkedIn', 700, False, 2003, 2003, 2003, 2003, 2003] ['WhatsApp', 2500, True, 2009, 2009, 2009, 2009, 2009]

# %%
lista_rrss=[fbk, ig, yt, lkn, wsp]
lista_rrss
# Out:
# [['Facebook', 2000, True],
#  ['Instagram', 1000, True],
#  ['Youtube', 3000, False],
#  ['LinkedIn', 700, False],
#  ['WhatsApp', 2500, True]]

# %%
import numpy as np
import pandas as pd
pd.DataFrame(lista_rrss, columns=['Nombre', 'Cantidad','es_perteciente'])
# Out:
#       Nombre  Cantidad  es_perteciente
# 0   Facebook      2000            True
# 1  Instagram      1000            True
# 2    Youtube      3000           False
# 3   LinkedIn       700           False
# 4   WhatsApp      2500            True
